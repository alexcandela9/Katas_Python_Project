# %% [markdown]
# 10. Escribe una función que reciba una lista de números y calcule su promedio. Si la lista está vacía, lanza una
# excepción personalizada y maneja el error adecuadamente.

# %%
class ListaVaciaError(Exception):              # Creamos una excepción personalizada
    pass                                       # No añadimos comportamiento extra

def promedio(lista):
    
    try:                           # Definimos la función
        if not lista:                              # Comprobamos si la lista está vacía
            raise ListaVaciaError("La lista está vacía")  # Lanzamos la excepción
        return sum(lista) / len(lista)                    # Calculamos y devolvemos el promedio
    
    except ListaVaciaError as l:

        print(f'Error controlado: {l}')

# %%
promedio([2,5,9])

promedio([])
# Out:
# Error controlado: La lista está vacía

# %% [markdown]
# raise
#
#     Lanza un error manualmente
#
#     Interrumpe la ejecución
#
# class MiError(Exception)
#
#     Crea un nuevo tipo de error
#
#     Hereda comportamiento de error normal
#
# Exception
#
#     Clase base de los errores
#
#     Hace que Python trate la clase como un error real
