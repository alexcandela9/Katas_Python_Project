# %% [markdown]
# 14. Crea una función que retorne las palabras de una lista de palabras que comience con una letra en especifico. Usa la
# función filter()

# %%
def filtro_n(lista, n):

    return list(filter(lambda x: x.lower().startswith(n.lower()), lista))

# %%
paises = ['España', 'andorra', 'estonia', 'Alemania']

print(filtro_n(paises, 'E'))
# Out:
# ['España', 'estonia']

# %% [markdown]
# Se ha puesto un .lower() al coger el primer caracter del elemento de la lista para que siempre sea minuscula.
#
# El caracter por el que empieza cada elemeto se coge con .startswith()
#
# Y se ha puesto tambien .lower() para que de igual la inicial escrita como filtro si esta en mayuscula o minuscula
