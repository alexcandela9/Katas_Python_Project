# %% [markdown]
# 23. Concatena una lista de palabras.Usa la función reduce() .

# %%
from functools import reduce      

def concatena(lista):

    if not isinstance(lista, list):
        raise TypeError("La función solo acepta UNA lista como argumento.")

    return reduce(lambda a,b: a+" "+b, lista)

# %%
concatena(["Hola", "y", "adios", ";", ")"])
# Out:
# 'Hola y adios ; )'

# %% [markdown]
# Si pasamos algo que no es una lista nos da el error que hemos programado.
#
# Pero si pasaramos 2 argumentos, daria error y no lo capturaria porque se produce antes del if, porque la funcion solo espera un argumento.

# %%
concatena(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 concatena(8)
#
# Cell In[25], line 6, in concatena(lista)
#       3 def concatena(lista):
#       5     if not isinstance(lista, list):
# ----> 6         raise TypeError("La función solo acepta UNA lista como argumento.")
#       8     return reduce(lambda a,b: a+" "+b, lista)
#
# TypeError: La función solo acepta UNA lista como argumento.
